# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Create (страницу «Hello, World»)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# create a new repository

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# add a page in repository

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# check the status of the repository

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# rename in main

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# we add "<h1>Hello, World!</h1>" in file hello.html after this we will check the status

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# add changes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Indexing and commit (Отдельный шаг индексации в Git позволяет вам разделять большие изменения на маленькие коммиты. Аналогия: вы помыли машину и заодно залили жидкость для очистки стекла — эти два изменения по своей сути независимы, а потому лучше пометить их отдельно. В противном случае, в истории изменений бачка для жидкости очистки стекла будет запись "Помыл машину", что не соответствует сути изменения и может запутать того, кто потом будет разбираться в этой истории.
#
# Предположим, что вы отредактировали три файла (a.html, b.html, и c.html). Теперь вы хотите закоммитить все изменения, при этом чтобы изменения в a.html и b.html были одним коммитом, в то время как изменения в c.html логически не связаны с первыми двумя файлами и должны идти отдельным коммитом.)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# commit changes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Изменения, а не файлы
# Цели
# Понять, что Git работает с изменениями, а не файлами.
# Большинство систем контроля версий работает с файлами: вы добавляете файл в систему, и она отслеживает изменения файла с этого момента.
#
# Git фокусируется на изменениях в файле, а не самом файле. Когда вы осуществляете команду git add file, вы не говорите Git добавить файл в репозиторий. Скорее вы говорите, что Git надо отметить текущее состояние файла, коммит которого будет произведен позже.

# %% [markdown]
# add changes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# check current status

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Commit

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# add a second changes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# do second commit for second changes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# check history

# %% [markdown]
# git log
# ![image.png](attachment:image.png)

# %% [markdown]
# One Line Story

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Final log format

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Git, позволяющих настроить формат вывода истории по умолчанию
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# get previous version

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Просмотрите историю изменений и найдите хеш первого коммита. Он должен быть в последней строке результата git log. Используйте этот хеш (достаточно первых 7 символов) в команде ниже. Затем проверьте содержимое файла hello.html.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# come back to the leatest version in the main branch

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# crate tag of version

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# tags for previous vefsions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Это версия с тегами <html> и <body>, но еще пока без <head>. Давайте сделаем ее версией v1-beta.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Switch by tag name

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# wiew tags using by comand

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# wiew tags in logs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# switch to branch main

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# check the status after changing the hello.html

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Reverting changes to the working directory(Отмена изменений в составе рабочих директоров)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Измените файл и проиндексируйте изменения
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Rebuilding the index(Восстановление индекса)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# rebuilding the working directory(Восстановление рабочего каталога)

# %% [markdown]
# ![image.png](attachment:image.png)
# Наша рабочая директория опять чиста.
